# %%
from geopy.geocoders import Nominatim

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Load river data from a shapefile
gpd_file = '/home/nimmoh/Documents/DE Projects/DE_learning/ne_110m_rivers_lake_centerlines/ne_110m_rivers_lake_centerlines.shx'
gpd_file2 ='/home/nimmoh/Documents/DE Projects/DE_learning/ne_110m_rivers_lake_centerlines/ne_110m_rivers_lake_centerlines.shp'
waterb1 = gpd.read_file(gpd_file)
waterb2 = gpd.read_file(gpd_file2)

# Load lake data from a GeoJSON file
#lakes = gpd.read_file('path_to_lakes.geojson')

# %%
print (waterb1.head())
print (waterb2.head())
# Out:
#    scalerank featurecla         name name_alt  min_zoom      name_en  \
# 0          2      River  Brahmaputra      NaN       2.1  Brahmaputra
# 1          2      River       Mekong      NaN       2.1       Mekong
# 2          2      River           Ob      NaN       2.1           Ob
# 3          2      River        Peace      NaN       2.1        Peace
# 4          2      River        Donau   Danube       2.1       Danube
#
#    min_label wikidataid        label          name_ar  ...      name_tr  \
# 0        3.1     Q45403  Brahmaputra  نهر براهمابوترا  ...  Brahmaputra
# 1        3.1     Q41179       Mekong       نهر ميكونغ  ...       Mekong
# 2        3.1       Q973           Ob             أوبي  ...          Obi
# 3        3.1      Q2220        Peace              بيس  ...        Peace
# 4        3.1      Q1653        Donau            دانوب  ...         Tuna
#
#        name_vi  name_zh       ne_id      name_he      name_uk  \
# ...

# %%
waterb1.plot()
plt.title('Water Bodies')

plt.show()

# %%
waterb2.plot(color='blue', edgecolor='black', linewidth=0.5)
# Out:
# <Axes: >

# %%
ax =  waterb1.plot(color='blue', edgecolor='black', linewidth=0.5)
waterb2.plot(ax=ax, color='cyan', linewidth=1.0)
# Out:
# <Axes: >

# %%
plt.savefig('water_bodies_visualization.png', dpi=300, bbox_inches='tight')
